# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

# %%
from pathlib import Path
import os

BASE_DIR = Path("../../data")
RAW_DIR = BASE_DIR / "raw" / "widsdatathon2025"
PROCESSED_DIR = BASE_DIR / "preprocessed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
train_solutions = pd.read_excel(RAW_DIR / "TRAIN/TRAINING_SOLUTIONS.xlsx")
train_solutions.head() 

# Extract the target variables
TARGET_VARS = ['participant_id', 'Sex_F', 'ADHD_Outcome']
target_df = train_solutions[TARGET_VARS]

# Define folder structures (same as the original script)
JOIN_TYPES = ['outer', 'left', 'right']
SCALING_METHODS = ['standard', 'minmax']
TRANSFORMATIONS = ['original', 'log', 'pca']  # Including PCA for completeness

#DOESN'T WORK DONT USE 
# the goal of this is to create a new csv where the old csv in whatever folder is merged with the target vars so we can finally 
# run smote on it 

# # Save the target variable CSV in each subfolder
# for join_type in JOIN_TYPES:
#     for scaling_method in SCALING_METHODS:
#         for transformation in TRANSFORMATIONS:
#             dir_path = PROCESSED_DIR / join_type / scaling_method / transformation
#             target_file_path = dir_path / "target_var_train.csv"

#             target_df.to_csv(target_file_path, index=False)
#             print(f"Target variables saved to {target_file_path}")
